# %%
import pandas as pd
df = pd.read_csv("solicitudes_credito.csv", sep=";")

# %%
del df['Unnamed: 0']
df = df.dropna().drop_duplicates()

# %%
df['sexo'] = df['sexo'].apply(str.lower)
df['tipo_de_emprendimiento'] = df['tipo_de_emprendimiento'].apply(str.lower)
df['idea_negocio'] = df['idea_negocio'].apply(lambda x: x.lower().replace('_', ' ').replace('-', ' '))
df['barrio'] = df['barrio'].apply(lambda x: x.lower().replace('_', '-').replace('-', ' '))
df['línea_credito'] = df['línea_credito'].apply(lambda x: x.lower().replace('_', ' ').replace('-', ' '))

# %%
df['monto_del_credito'] = df['monto_del_credito'].str.replace(',', '').str.replace('$', '', regex=False).str.replace(' ', '').astype(float)
df['fecha_de_beneficio'] = pd.to_datetime(df['fecha_de_beneficio'], dayfirst=True)
df = df.drop_duplicates().dropna()
df.reset_index(drop = True)
# Out:
#             sexo tipo_de_emprendimiento          idea_negocio  \
# 0      masculino               comercio           charcuteria
# 1      masculino               comercio     distribuidora de
# 2      masculino               comercio                tienda
# 3      masculino               servicio       organización y
# 4      masculino               servicio       comidas rapidas
# ...          ...                    ...                   ...
# 10201   femenino               comercio   almacen de ropa en
# 10202   femenino               comercio             cafeteria
# 10203   femenino              industria             cafeteria
# 10204   femenino               comercio   almacen de ropa en
# 10205   femenino               servicio  fabrica de alimentos
#
#                        barrio  estrato  comuna_ciudadano fecha_de_beneficio  \
# 0      manrique central no. 2        1               3.0         2017-12-28
# 1                 santa lucia        2              12.0         2018-03-16
# 2                       belen        3              16.0         2018-02-14
# 3                     robledo        2               7.0         2016-09-08
# 4                 20 de julio        2              13.0         2016-12-20
# ...                       ...      ...               ...                ...
# 10201      campo valdes no. 1        3               4.0         2018-07-04
# 10202              la america        3              12.0         2018-03-20
# 10203    santo domingo savio         1               1.0         2018-06-22
# 10204                  caribe        3               5.0         2019-02-27
# 10205               andalucia        2               2.0         2017-06-08
#
#        monto_del_credito     línea_credito
# 0              7000000.0  microempresarial
# 1              7000000.0  microempresarial
# 2              7800000.0  microempresarial
# 3              1500000.0  microempresarial
# 4              3000000.0  microempresarial
# ...                  ...               ...
# 10201          2000000.0  microempresarial
# 10202          5000000.0  microempresarial
# 10203          1000000.0  microempresarial
# 10204          8281000.0  microempresarial
# 10205         30000000.0  empresarial ed.
#
# [10206 rows x 9 columns]

# %%
df
# Out:
#             sexo tipo_de_emprendimiento          idea_negocio  \
# 0      masculino               comercio           charcuteria
# 1      masculino               comercio     distribuidora de
# 2      masculino               comercio                tienda
# 3      masculino               servicio       organización y
# 4      masculino               servicio       comidas rapidas
# ...          ...                    ...                   ...
# 10913   femenino               comercio   almacen de ropa en
# 10914   femenino               comercio             cafeteria
# 10915   femenino              industria             cafeteria
# 10918   femenino               comercio   almacen de ropa en
# 10919   femenino               servicio  fabrica de alimentos
#
#                        barrio  estrato  comuna_ciudadano fecha_de_beneficio  \
# 0      manrique central no. 2        1               3.0         2017-12-28
# 1                 santa lucia        2              12.0         2018-03-16
# 2                       belen        3              16.0         2018-02-14
# 3                     robledo        2               7.0         2016-09-08
# 4                 20 de julio        2              13.0         2016-12-20
# ...                       ...      ...               ...                ...
# 10913      campo valdes no. 1        3               4.0         2018-07-04
# 10914              la america        3              12.0         2018-03-20
# 10915    santo domingo savio         1               1.0         2018-06-22
# 10918                  caribe        3               5.0         2019-02-27
# 10919               andalucia        2               2.0         2017-06-08
#
#        monto_del_credito     línea_credito
# 0              7000000.0  microempresarial
# 1              7000000.0  microempresarial
# 2              7800000.0  microempresarial
# 3              1500000.0  microempresarial
# 4              3000000.0  microempresarial
# ...                  ...               ...
# 10913          2000000.0  microempresarial
# 10914          5000000.0  microempresarial
# 10915          1000000.0  microempresarial
# 10918          8281000.0  microempresarial
# 10919         30000000.0  empresarial ed.
#
# [10206 rows x 9 columns]

# %%
Grupos = df['sexo'].value_counts().to_list()
Grupos
# Out:
# [6617, 3589]
